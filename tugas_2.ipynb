# %%
import statistics
import pandas as pd
import numpy as np
from scipy import stats

# %%
print("====01=====")
print ("=== tamat s2====")
a = 0
b = 1
c = 4
d = 7
e = 5
f = 0
 
hasil = (a + b) + (c + d) + (e + f)
print ("maka jumlah orang tamat s2 = " + str(hasil))

print ("=== tamat s1====")
a = 4
b = 12
c = 6
d = 13
e = 14
f = 0
 
hasil = (a + b) + (c + d) + (e + f)
print ("maka jumlah orang tamat s1 = " + str(hasil))

print ("=== tamat sma====")
a = 12
b = 17
c = 5
d = 20
e = 11
f = 75
 
hasil = (a + b) + (c + d) + (e + f)
print ("maka jumlah orang tamat smp = " + str(hasil))

print ("=== tamat smp====")
a = 5
b = 6
c = 15
d = 9
e = 20
f = 15
 
hasil = (a + b) + (c + d) + (e + f)
print ("maka jumlah orang tamat smp = " + str(hasil))

print ("=== tamat sd====")
a = 1
b = 8
c = 0
d = 19
e = 10
f = 1
 
hasil = (a + b) + (c + d) + (e + f)
print ("maka jumlah orang tamat sd = " + str(hasil))

print ("=== tidak diketahui====")
a = 2
b = 14
c = 3
d = 10
e = 0
f = 1
 
hasil = (a + b) + (c + d) + (e + f)
print ("maka jumlah orang tidak diketahui = " + str(hasil))

print("====02====")

#s2

a = 17
b = 0.25
hasil = (a * b)
print("maka mutu pendidikan s2 adalah =" + str(hasil))

#s1

a = 49
b = 0.20
hasil = (a * b)
print("maka mutu pendidikan s1 adalah =" + str(hasil))

#sma

a = 140
b = 0.15
hasil = (a * b)
print("maka mutu pendidikan sma adalah =" + str(hasil))

#smp

a = 70
b = 0.10
hasil = (a * b)
print("maka mutu pendidikan smp adalah =" + str(hasil))

#sd

a = 39
b = 0.5
hasil = (a * b)
print("maka mutu pendidikan sd adalah =" + str(hasil))

#tidak diketahui

a = 30
b = 0.3
hasil = (a * b)
print("maka mutu pendidikan tidak diketahui adalah =" + str(hasil))

print("===03====")
print("===rentang 70===")
a = 0
b = 0.25
hasil = (a * b)
print("maka mutu tamat s2 adalah =" + str(hasil))

a = 4
b = 0.20
hasil = (a * b)
print("maka mutu tamat s1 adalah =" + str(hasil))

a = 12
b = 0.15
hasil = (a * b)
print("maka mutu tamat sma adalah =" + str(hasil))

a = 5
b = 0.10
hasil = (a * b)
print("maka mutu tamat smp adalah =" + str(hasil))

a = 1
b = 0.5
hasil = (a * b)
print("maka mutu tamat sd adalah =" + str(hasil))

a = 2
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah =" + str(hasil))

a = 0.0
b = 0.8
c = 1.7999999999999998
d = 0.5
e = 0.5
f = 0.6

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang >70 adalah =" + str(hasil))

print("===rentang 60===")
a = 1
b = 0.25
hasil = (a * b)
print("maka mutu tamat s2 adalah =" + str(hasil))

a = 12
b = 0.20
hasil = (a * b)
print("maka mutu tamat s1 adalah =" + str(hasil))

a = 17
b = 0.15
hasil = (a * b)
print("maka mutu tamat sma adalah =" + str(hasil))

a = 6
b = 0.10
hasil = (a * b)
print("maka mutu tamat smp adalah =" + str(hasil))

a = 8
b = 0.5
hasil = (a * b)
print("maka mutu tamat sd adalah =" + str(hasil))

a = 14
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah =" + str(hasil))

a = 0.25
b = 2.4000000000000004
c = 2.55
d = 0.6000000000000001
e = 4.0
f = 4.2

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang >60 adalah =" + str(hasil))

print("===rentang 50===")
a = 4
b = 0.25
hasil = (a * b)
print("maka mutu tamat s2 adalah =" + str(hasil))

a = 6
b = 0.20
hasil = (a * b)
print("maka mutu tamat s1 adalah =" + str(hasil))

a = 5
b = 0.15
hasil = (a * b)
print("maka mutu tamat sma adalah =" + str(hasil))

a = 15
b = 0.10
hasil = (a * b)
print("maka mutu tamat smp adalah =" + str(hasil))

a = 0
b = 0.5
hasil = (a * b)
print("maka mutu tamat sd adalah =" + str(hasil))

a = 3
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah =" + str(hasil))

a = 1.0
b = 1.2000000000000002
c = 0.75
d = 1.5
e = 0.0
f = 0.8999999999999999

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang >50 adalah =" + str(hasil))

print("===rentang 40===")
a = 7
b = 0.25
hasil = (a * b)
print("maka mutu tamat s2 adalah =" + str(hasil))

a = 13
b = 0.20
hasil = (a * b)
print("maka mutu tamat s1 adalah =" + str(hasil))

a = 20
b = 0.15
hasil = (a * b)
print("maka mutu tamat sma adalah =" + str(hasil))

a = 9
b = 0.10
hasil = (a * b)
print("maka mutu tamat smp adalah =" + str(hasil))

a = 19
b = 0.5
hasil = (a * b)
print("maka mutu tamat sd adalah =" + str(hasil))

a = 10
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah =" + str(hasil))

a = 1.75
b = 2.6
c = 3.0
d = 0.9
e = 9.5
f = 3.0

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang >40 adalah =" + str(hasil))

print("===rentang 30===")
a = 5
b = 0.25
hasil = (a * b)
print("maka mutu tamat s2 adalah =" + str(hasil))

a = 14
b = 0.20
hasil = (a * b)
print("maka mutu tamat s1 adalah =" + str(hasil))

a = 11
b = 0.15
hasil = (a * b)
print("maka mutu tamat sma adalah =" + str(hasil))

a = 20
b = 0.10
hasil = (a * b)
print("maka mutu tamat smp adalah =" + str(hasil))

a = 10
b = 0.5
hasil = (a * b)
print("maka mutu tamat sd adalah =" + str(hasil))

a = 0
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah =" + str(hasil))

a = 1.25
b = 2.8000000000000003
c = 1.65
d = 2.0
e = 5.0
f = 0.0

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang >30 adalah =" + str(hasil))

print("===rentang 20===")
a = 0
b = 0.25
hasil = (a * b)
print("maka mutu tamat s2 adalah =" + str(hasil))

a = 0
b = 0.20
hasil = (a * b)
print("maka mutu tamat s1 adalah =" + str(hasil))

a = 75
b = 0.15
hasil = (a * b)
print("maka mutu tamat sma adalah =" + str(hasil))

a = 15
b = 0.10
hasil = (a * b)
print("maka mutu tamat smp adalah =" + str(hasil))

a = 1
b = 0.5
hasil = (a * b)
print("maka mutu tamat sd adalah =" + str(hasil))

a = 1
b = 0.3
hasil = (a * b)
print("maka mutu tidak diketahui adalah =" + str(hasil))

a = 0.0
b = 0.0
c = 11.25
d = 1.5
e = 0.5
f = 0.3

hasil = (a + b) + (c + d) + (e + f)
print("maka hasil rentang >20 adalah =" + str(hasil))

print("=====04====")

min = [4.199999999999999]
print("maka yang paling kecil dari rentang usia adalah usia >70 " +str(min))
# Out:
# ====01=====
# === tamat s2====
# maka jumlah orang tamat s2 = 17
# === tamat s1====
# maka jumlah orang tamat s1 = 49
# === tamat sma====
# maka jumlah orang tamat smp = 140
# === tamat smp====
# maka jumlah orang tamat smp = 70
# === tamat sd====
# maka jumlah orang tamat sd = 39
# === tidak diketahui====
# maka jumlah orang tidak diketahui = 30
# ====02====
# maka mutu pendidikan s2 adalah =4.25
# maka mutu pendidikan s1 adalah =9.8
# maka mutu pendidikan sma adalah =21.0
# maka mutu pendidikan smp adalah =7.0
# maka mutu pendidikan sd adalah =19.5
# maka mutu pendidikan tidak diketahui adalah =9.0
# ===03====
# ===rentang 70===
# maka mutu tamat s2 adalah =0.0
# maka mutu tamat s1 adalah =0.8
# maka mutu tamat sma adalah =1.7999999999999998
# maka mutu tamat smp adalah =0.5
# maka mutu tamat sd adalah =0.5
# maka mutu tidak diketahui adalah =0.6
# maka hasil rentang >70 adalah =4.199999999999999
# ===rentang 60===
# maka mutu tamat s2 adalah =0.25
# ...

# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
pendidikan = ['s2','s1', 'sma', 'smp', 'sd', 'tidak diketahui']
hasil = [17, 49, 140, 70, 39, 30]
c = ['red', 'green', 'blue']
plt.title("pendidikan")
plt.bar (pendidikan, hasil,  color = c)
plt.show()
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
usia = ['70','60', '50', '40', '30', '20']
hasil = [4.199999999999999, 14.0, 5.35, 20.75,12.700000000000001, 13.55 ]
c = ['red', 'green', 'blue']
plt.title("usia")
plt.bar (usia, hasil,  color = c)
plt.show()

# %%
import matplotlib.pyplot as plt
#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("pendidikan")
pendidikan = ['s2','s1', 'sma', 'smp', 'sd', 'tidak diketahui']
hasil = [17, 49, 140, 70, 39, 30]
ax.pie(hasil,labels=pendidikan,autopct='%1.2f%%')
plt.show()
import matplotlib.pyplot as plt
#pie chart
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.axis('equal')
plt.title("usia")
usia = ['70','60', '50', '40', '30', '20']
hasil = [4.199999999999999, 14.0, 5.35, 20.75,12.700000000000001, 13.55 ]
ax.pie(hasil,labels=usia,autopct='%1.2f%%')
plt.show()
